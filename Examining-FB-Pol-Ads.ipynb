# %% [markdown]
# # Examining ProPublica's Facebook Political Ad Data

# %% [markdown]
# ## Getting the data

# %% [markdown]
# The data can be downloaded [here](https://www.propublica.org/datastore/dataset/political-advertisements-from-facebook). You don't have to provide your name, email or organization, but you do have to agree to abide by ProPublica's [Terms of Use](https://www.propublica.org/datastore/terms).

# %% [markdown]
# ## Filtering to Ads targeted to Missouri

# %% [markdown]
# We'll use [pandas](https://pandas.pydata.org/) to read in the .csv file, and filter it to only Missouri-related ads.

# %%
import pandas as pd

# %%
ads = pd.read_csv("fbpac-ads-en-us.csv")

# %% [markdown]
# ### How many total ads?

# %%
len(ads)
# Out:
# 64636

# %% [markdown]
# Here's a quick look a the top five rows in the file.

# %%
ads.head()
# Out:
#                   id                                               html  \
# 0  23842934264470055  <div class="_5pcr userContentWrapper"><div cla...
# 1  23843007348380279  <div class="_5pa- userContentWrapper"><div cla...
# 2  23842930304260339  <div class="_5pcr userContentWrapper"><div cla...
# 3      6106200884302  <div class="_5pcr userContentWrapper"><div cla...
# 4  23843007362830528  <div class="_5pcr userContentWrapper"><div cla...
#
#    political  not_political                    title  \
# 0          5              0           Blue Wave 2018
# 1          7              0            Beto O'Rourke
# 2          6              0            Phil Bredesen
# 3          4              1  Emerson College Polling
# 4          5              1                Be A Hero
#
#                                              message  \
# 0         <p>Robert Mueller is an American hero!</p>
# 1  <p>BREAKING: Politico just reported that GOP L...
# 2  <p>Too many Tennesseans in rural communities d...
# 3  <p>And so our poll of the week is an <a class=...
# 4  <p>Clearly calls, emails, and visits are not w...
#
#                                            thumbnail  \
# 0  https://pp-facebook-ads.s3.amazonaws.com/v/t1....
# 1  https://pp-facebook-ads.s3.amazonaws.com/v/t1....
# 2  https://pp-facebook-ads.s3.amazonaws.com/v/t1....
# 3  https://pp-facebook-ads.s3.amazonaws.com/v/t1....
# 4  https://pp-facebook-ads.s3.amazonaws.com/v/t1....
#
#                       created_at                     updated_at   lang  \
# 0  2018-08-27 18:34:00.351869+00  2018-08-28 13:13:35.255391+00  en-US
# 1  2018-08-23 16:17:45.244313+00  2018-09-06 00:11:41.161539+00  en-US
# 2  2018-08-27 18:11:13.179067+00  2018-08-30 01:37:36.504856+00  en-US
# 3  2018-08-27 18:35:46.511049+00  2018-08-28 13:13:11.850585+00  en-US
# 4  2018-08-29 17:41:48.659359+00  2018-08-30 11:52:20.125079+00  en-US
#
#       ...                                               targeting  suppressed  \
# 0     ...       <div><div class="_4-i0 _26c5"><div class="clea...           f
# 1     ...       <div><div class="_4-i0 _26c5"><div class="clea...           f
# 2     ...       <div><div class="_4-i0 _26c5"><div class="clea...           f
# 3     ...       <div><div class="_4-i0 _26c5"><div class="clea...           f
# 4     ...       <div><div class="_4-i0 _26c5"><div class="clea...           f
#
#                                              targets               advertiser  \
# 0  [{"target": "Age", "segment": "18 and older"},...           Blue Wave 2018
# 1  [{"target": "Age", "segment": "18 and older"},...            Beto O'Rourke
# 2  [{"target": "Age", "segment": "18 and older"},...            Phil Bredesen
# 3  [{"target": "Age", "segment": "18 and older"},...  Emerson College Polling
# 4  [{"target": "Age", "segment": "18 and older"},...                Be A Hero
#
#                                             entities  \
# 0  [{"entity": "Robert Mueller", "entity_type": "...
# 1  [{"entity": "Texas", "entity_type": "Region"},...
# 2  [{"entity": "TVA", "entity_type": "Organizatio...
# 3  [{"entity": "Emerson College", "entity_type": ...
# 4  [{"entity": "U.S.", "entity_type": "Region"}, ...
#
#                                                 page  \
# 0  https://www.facebook.com/Blue-Wave-2018-222012...
# 1              https://www.facebook.com/betoorourke/
# 2        https://www.facebook.com/BredesenForSenate/
# 3           https://www.facebook.com/emersonpolling/
# 4              https://www.facebook.com/BeAHeroTeam/
#
#                                           lower_page  \
# 0  https://www.facebook.com/blue-wave-2018-222012...
# 1              https://www.facebook.com/betoorourke/
# 2        https://www.facebook.com/bredesenforsenate/
# 3           https://www.facebook.com/emersonpolling/
# 4              https://www.facebook.com/beaheroteam/
#
#                                           targetings              paid_for_by  \
# 0  {"<div><div class=\"_4-i0 _26c5\"><div class=\...           Blue Wave 2018
# 1  {"<div><div class=\"_4-i0 _26c5\"><div class=\...           Beto for Texas
# 2  {"<div><div class=\"_4-i0 _26c5\"><div class=\...      Bredesen for Senate
# 3  {"<div><div class=\"_4-i0 _26c5\"><div class=\...  Emerson College Polling
# 4  {"<div><div class=\"_4-i0 _26c5\"><div class=\...            Be a Hero PAC
#
#   targetedness
# 0          3.0
# 1          1.0
# 2          3.0
# 3          2.0
# 4          1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Filtering by `targets`

# %% [markdown]
# Looks's like we want to use the `targets` in our filter criteria. It contains what looks like a JSON string: an array of JSON objects. Let's take a closer look at the distinct values of this column.

# %%
ads.targets.value_counts()
# Out:
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                     6317
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                    5642
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "the United States"}, {"target": "List"}]                                                                                                                                                                                                                                                                                       4859
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "the United States"}, {"target": "Like"}]                                                                                                                                                                                                                                                                                       2179
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Website", "segment": "people who have visited their website or used one of their apps"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                      2085
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                                                                           1775
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "the United States"}, {"target": "Activity on the Facebook Family"}]                                                                                                                                                                                                                                                            1010
# [{"target": "Age", "segment": "30 and older"}, {"target": "MinAge", "segment": "30"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                      642
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Segment", "segment": "US politics (very liberal)"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                            600
# [{"target": "Age", "segment": "45 and older"}, {"target": "MinAge", "segment": "45"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                      412
# [{"target": "Age", "segment": "25 and older"}, {"target": "MinAge", "segment": "25"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                      394
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Segment", "segment": "Member of a family-based household."}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                   344
# [{"target": "Age", "segment": "35 and older"}, {"target": "MinAge", "segment": "35"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                      335
# [{"target": "Age", "segment": "21 and older"}, {"target": "MinAge", "segment": "21"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                      315
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Bernie Sanders"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                       311
# [{"target": "Age", "segment": "25 and older"}, {"target": "MinAge", "segment": "25"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                                                                            296
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Democratic Party (United States)"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                     255
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "California"}, {"target": "Like"}]                                                                                                                                                                                                                                                                                               214
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}]                                                                                                                                                                                                                                                                            210
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Texas"}, {"target": "Like"}]                                                                                                                                                                                                                                                                                                    196
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Florida"}, {"target": "List"}]                                                                                                                                                                                                                                                                                                  191
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "California"}, {"target": "List"}]                                                                                                                                                                                                                                                                                               187
# [{"target": "Age", "segment": "40 and older"}, {"target": "MinAge", "segment": "40"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                      172
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "New York"}, {"target": "List"}]                                                                                                                                                                                                                                                                                                 168
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Bellingham"}, {"target": "State", "segment": "Washington"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}]                                                                                                                                                                                 159
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Barack Obama"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                         153
# [{"target": "List"}, {"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                                                        149
# [{"target": "Retargeting", "segment": "people who may be similar to their customers"}, {"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                      141
# [{"target": "Retargeting", "segment": "people who may be similar to their customers"}, {"target": "Age", "segment": "18 and older"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                             131
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Segment", "segment": "US politics (liberal)"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                 125
#                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Dearborn"}, {"target": "Interest", "segment": "Earthjustice"}, {"target": "City", "segment": "Federal Way"}, {"target": "State", "segment": "Michigan"}, {"target": "State", "segment": "Washington"}]                                                                                                                              1
# [{"target": "Interest", "segment": "Netflix"}, {"target": "Age", "segment": "18 to 60"}, {"target": "MinAge", "segment": "18"}, {"target": "MaxAge", "segment": "60"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                             1
# [{"target": "Interest", "segment": "National Park Service"}, {"target": "Age", "segment": "55 and older"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                                                         1
# [{"target": "Age", "segment": "25 and older"}, {"target": "MinAge", "segment": "25"}, {"target": "City", "segment": "Austin"}, {"target": "Interest", "segment": "Politics and social issues"}, {"target": "State", "segment": "Texas"}]                                                                                                                                                                                                                 1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Milton"}, {"target": "State", "segment": "Ontario"}]                                                                                                                                                                                                                                                                                1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Grand Prairie"}, {"target": "State", "segment": "Texas"}, {"target": "Retargeting", "segment": "recently near their business"}]                                                                                                                                                                                                     1
# [{"target": "Age", "segment": "25 and older"}, {"target": "MinAge", "segment": "25"}, {"target": "Region", "segment": "New Mexico"}]                                                                                                                                                                                                                                                                                                                     1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Bernie Sanders"}, {"target": "Region", "segment": "Iowa"}]                                                                                                                                                                                                                                                                      1
# [{"target": "Age", "segment": "35 and older"}, {"target": "MinAge", "segment": "35"}, {"target": "Interest", "segment": "Environmentalism"}, {"target": "State", "segment": "Florida"}, {"target": "City", "segment": "Fort Lauderdale"}]                                                                                                                                                                                                                1
# [{"target": "Age", "segment": "35 and older"}, {"target": "MinAge", "segment": "35"}, {"target": "Region", "segment": "Oregon"}, {"target": "Interest", "segment": "Politics and social issues"}]                                                                                                                                                                                                                                                        1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Community issues"}, {"target": "City", "segment": "Maryland Heights"}, {"target": "State", "segment": "Missouri"}]                                                                                                                                                                                                              1
# [{"target": "Age", "segment": "21 and older"}, {"target": "MinAge", "segment": "21"}, {"target": "Interest", "segment": "Sustainable energy"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                     1
# [{"target": "Age", "segment": "36 and older"}, {"target": "MinAge", "segment": "36"}, {"target": "Interest", "segment": "The Intercept"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                                          1
# [{"target": "Age", "segment": "16 and older"}, {"target": "MinAge", "segment": "16"}, {"target": "Interest", "segment": "Democratic Party (United States)"}, {"target": "State", "segment": "Maryland"}, {"target": "City", "segment": "Potomac"}, {"target": "City", "segment": "Redland"}]                                                                                                                                                             1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Maine"}, {"target": "City", "segment": "Portland"}, {"target": "Like"}]                                                                                                                                                                                                                                                            1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Conroe"}, {"target": "State", "segment": "Texas"}, {"target": "City", "segment": "The Woodlands"}]                                                                                                                                                                                                                                  1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Massachusetts"}, {"target": "City", "segment": "Worcester"}]                                                                                                                                                                                                                                                                       1
# [{"target": "Age", "segment": "25 and older"}, {"target": "MinAge", "segment": "25"}, {"target": "Interest", "segment": "Civil and political rights"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                                                                                                                                                      1
# [{"target": "Age", "segment": "21 and older"}, {"target": "MinAge", "segment": "21"}, {"target": "Interest", "segment": "Democratic Party (United States)"}, {"target": "State", "segment": "Florida"}, {"target": "City", "segment": "Sarasota"}]                                                                                                                                                                                                       1
# [{"target": "Age", "segment": "18 to 55"}, {"target": "MinAge", "segment": "18"}, {"target": "MaxAge", "segment": "55"}, {"target": "Region", "segment": "Texas"}]                                                                                                                                                                                                                                                                                       1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Arizona"}, {"target": "Interest", "segment": "World Wide Fund for Nature"}]                                                                                                                                                                                                                                                       1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "North Carolina Central University"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                      1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Burlington"}, {"target": "City", "segment": "Chicago"}, {"target": "State", "segment": "Illinois"}, {"target": "City", "segment": "New York"}, {"target": "State", "segment": "New York"}, {"target": "City", "segment": "Seattle"}, {"target": "State", "segment": "Vermont"}, {"target": "State", "segment": "Washington"}]       1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Wendy Davis (politician)"}, {"target": "Region", "segment": "the United States"}]                                                                                                                                                                                                                                               1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Tennessee"}, {"target": "Website", "segment": "people who have visited their website or used one of their apps"}]                                                                                                                                                                                                                 1
# [{"target": "Interest", "segment": "Democratic Party (United States)"}, {"target": "Age", "segment": "35 and older"}, {"target": "City", "segment": "San Diego"}, {"target": "State", "segment": "California"}]                                                                                                                                                                                                                                          1
# [{"target": "Age", "segment": "18 to 42"}, {"target": "MinAge", "segment": "18"}, {"target": "MaxAge", "segment": "42"}, {"target": "City", "segment": "Ann Arbor"}, {"target": "State", "segment": "Michigan"}, {"target": "Interest", "segment": "Politics and social issues"}]                                                                                                                                                                        1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "France"}, {"target": "Segment", "segment": "Member of a family-based household."}]                                                                                                                                                                                                                                                1
# [{"target": "Age", "segment": "60 and older"}, {"target": "MinAge", "segment": "60"}, {"target": "Region", "segment": "the United States"}, {"target": "List"}]                                                                                                                                                                                                                                                                                          1
# [{"target": "Age", "segment": "60 and older"}, {"target": "MinAge", "segment": "60"}, {"target": "State", "segment": "Maine"}, {"target": "City", "segment": "Wayne"}, {"target": "List"}]                                                                                                                                                                                                                                                               1
# Name: targets, Length: 9771, dtype: int64

# %% [markdown]
# Each JSON object in each array appears to have two keys: `"target"` and `"segment"`. Just scrolling through the above values, I see objects `"target": "State"` paired with a state name in the `"segment"` value. However, I also see objects with `"target": "Region"` with a state name in the `"segment"` value.

# %% [markdown]
# A mapping of distinct `"target"` values to their `"segment"` values would be helpful. Let's build that mapping in the stupid, obvious way.

# %%
targets_to_segments = {}

# %% [markdown]
# We'll need to parse the json strings in the `targets` columns.

# %%
import json

# %% [markdown]
# Iterate over each row, then iterate over each target for the row, add the `"target"` value to the `targets_to_segments` dict (if it isn't already there), then add the `"segment"` value to the associated array (if it isn't already there).

# %%
for row in ads.iterrows():
    try:
        targets = json.loads(row[1]['targets'])
    except TypeError:
        # Ignore an value we can't parse as json (prob some variant of NULL)
        pass
    for target in targets:
        target_value = target['target']
        if target_value not in targets_to_segments:
            targets_to_segments[target_value] = []
        if 'segment' in target:
            if target['segment'] not in targets_to_segments[target_value]:
                targets_to_segments[target_value].append(target['segment'])

# %% [markdown]
# ### Targeting options

# %%
for k in targets_to_segments:
    print(k)
# Out:
# Age
# MinAge
# Retargeting
# Region
# Interest
# Like
# Activity on the Facebook Family
# MaxAge
# Gender
# List
# City
# State
# Website
# Segment
# Agency
# Language
# Engaged with Content

# %% [markdown]
# `"Region"`, `"State"` and `"City"` seem most relevant to the purposes of location-based filtering.

# %% [markdown]
# ### Region segments

# %%
for i in sorted(targets_to_segments["Region"]):
    print(i)
# Out:
# Alabama
# Alaska
# Alberta
# Arizona
# Arkansas
# Australia
# Australian Capital Territory
# Austria
# Belgium
# California
# Canada
# Colorado
# Connecticut
# Delaware
# District of Columbia
# England
# Florida
# France
# Georgia
# Germany
# Hawaii
# Idaho
# Illinois
# Indiana
# Indonesia
# Iowa
# Israel
# Kansas
# Kentucky
# Latvia
# Latvija
# Louisiana
# Maine
# Maryland
# Massachusetts
# Mexico
# Michigan
# Minnesota
# Missouri
# Montana
# Nebraska
# Netherlands
# Nevada
# New Brunswick
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
#
# Tempe
# Temple Terrace
# The Woodlands
# Thunder Bay
# Ticonderoga
# Toms River
# Topeka
# Toronto
# Towson
# Tripoli
# Troy
# Trumbull
# Trussville
# Truth or Consequences
# Tualatin
# Tucker
# Tucson
# Tuscaloosa
# Twentynine Palms
# Twinsburg
# University City
# Upper Arlington
# Urbana
# Vacaville
# Valhalla
# Valparaiso
# Vancouver
# Venice
# Victorville
# Villa Park
# Wadhams
# Wahpeton
# Wake Forest
# Waldorf
# Waldport
# Walla Walla
# Warren
# Washington
# Washington Four
# Wasilla
# Watertown
# Waukesha
# Wauwatosa
# Waverly
# Wayne
# Waynesboro
# Wellesley
# West Chester
# West Des Moines
# West Egg Harbor
# West Hartford
# West Haven
# West Jordan
# West Richland
# West University Place
# Westerville
# Westland
# Westminster
# Westport
# Wheaton
# Wheeling
# White Bear Lake
# White Hall
# White Plains
# Wichita
# Williamsburg
# Wilmington
# Winchester
# Winona
# Winooski
# Wisconsin Rapids
# Woodinville
# Wooster
# Worcester
# Wurtsboro
# Yonkers
# Yorba Linda
# York
# Youngstown
# Zimmerman
# Zion Crossroads
# Zionsville
# der Nähe von Basel

# %% [markdown]
# ### Does ever ad with a `"City"` target also include `"State"` target?

# %%
targets_w_city_wo_state = []
for row in ads.iterrows():
    try:
        targets = json.loads(row[1]['targets'])
    except TypeError:
        # Ignore an value we can't parse as json (prob some variant of NULL)
        pass
    has_city = 'City' in [i['target'] for i in targets]
    has_state = 'State' in [i['target'] for i in targets]
    if has_city and not has_state:
        targets_w_city_wo_state.append(targets)

# %%
len(targets_w_city_wo_state)
# Out:
# 0

# %% [markdown]
# Looks like yes (phew).

# %% [markdown]
# ## Filtering to ads targeted to Missouri (as a `"State"` or `"Region"`)

# %% [markdown]
# Since my pandas skills are rusty (particularly with JSON in the mix), we'll just do this the stupid, obvious way.

# %% [markdown]
# Here's a placeholder for all the records we want.

# %%
mo_ads = []

# %% [markdown]
# Loop over the dataframe, if `targets` includes a `"segment"` value of `"Missouri"`, keep it.

# %%
for row in ads.iterrows():
    try:
        targets = json.loads(row[1]['targets'])
    except TypeError:
        # Ignore an value we can't parse as json (prob some variant of NULL)
        pass
    has_mo = False
    for target in targets:
        if 'segment' in target.keys():
            if target['segment'] == 'Missouri':
                has_mo = True
    if has_mo:
        mo_ads.append(row[1])

# %% [markdown]
# ### How many Missouri ads?

# %%
len(mo_ads)
# Out:
# 546

# %% [markdown]
# ### Outputting to a new .csv

# %% [markdown]
# Now open a new csv file, and write each Missouri ad to it.

# %%
from csv import DictWriter

# %%
with open('fbpac-ads-MO.csv', 'w', newline='') as f:
    writer = DictWriter(f, fieldnames=list(ads))
    writer.writeheader()
    for ad in mo_ads:
        writer.writerow(ad.to_dict())

# %% [markdown]
# ## Double-check

# %% [markdown]
# Let's read this new file back in and make sure there aren't any obvious problems.

# %%
out_ads = pd.read_csv("fbpac-ads-mo.csv")

# %%
len(out_ads)
# Out:
# 546

# %% [markdown]
# ### Check that `id` values are unique

# %%
out_ads.id.value_counts()
# Out:
# 23842922325240188    1
# 6083893229461        1
# 23843009419610078    1
# 23842777351530276    1
# 23843020430170078    1
# 6093655990164        1
# 6101521429387        1
# 6084252953484        1
# 6103275672450        1
# 6110123039825        1
# 6082889133958        1
# 23843029742130097    1
# 6101667484669        1
# 6082762828797        1
# 23842905051200327    1
# 6092685613799        1
# 6086171725715        1
# 6096401233821        1
# 23842793773750057    1
# 23842928501490539    1
# 6084948361115        1
# 23842860179640091    1
# 23843029757700078    1
# 23842668246350404    1
# 6104954851235        1
# 23842764633890569    1
# 6092552200098        1
# 6088548954028        1
# 23842744374140678    1
# 23842749495480239    1
#                     ..
# 23842858515150078    1
# 23842932896900105    1
# 23843020619610078    1
# 6078729561171        1
# 23842746625450239    1
# 6092685605599        1
# 23842865664640239    1
# 23842728912550140    1
# 23842974931920594    1
# 6102978643035        1
# 23842848462330086    1
# 23842720688950517    1
# 23843118283120697    1
# 6096743898867        1
# 6097132025861        1
# 23842875031270621    1
# 23842773361250519    1
# 23842733660600539    1
# 6094838117261        1
# 6096331510021        1
# 6107273324661        1
# 23843020446050078    1
# 23842753685560539    1
# 23842773360440519    1
# 6089244706154        1
# 6088889785470        1
# 23842956666070078    1
# 6075192169599        1
# 6096419751035        1
# 6088295653061        1
# Name: id, Length: 546, dtype: int64

# %% [markdown]
# ### Check distinct `targets` values

# %%
out_ads.targets.value_counts()
# Out:
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Missouri"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}]                                                                                                               59
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Missouri"}, {"target": "List"}]                                                                                                                                                                                 50
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                                                                                                     32
# [{"target": "Age", "segment": "50 to 64"}, {"target": "MinAge", "segment": "50"}, {"target": "MaxAge", "segment": "64"}, {"target": "Region", "segment": "Missouri"}, {"target": "List"}]                                                                                                                                              26
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Democratic Party (United States)"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                              16
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Missouri"}, {"target": "Like"}]                                                                                                                                                                                 16
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}]                                                                                                                                                          14
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "St. Louis"}, {"target": "List"}]                                                                                                                                      10
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "St. Louis"}]                                                                                                                                                          10
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Maryland Heights"}, {"target": "State", "segment": "Missouri"}, {"target": "Website", "segment": "people who have visited their website or used one of their apps"}]                                               8
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Democratic Party (United States)"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}]                                                                                    8
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}]                                                                     7
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Columbia"}, {"target": "State", "segment": "Missouri"}, {"target": "Interest", "segment": "Politics"}]                                                                                                             6
# [{"target": "Age", "segment": "35 and older"}, {"target": "MinAge", "segment": "35"}, {"target": "Region", "segment": "Missouri"}, {"target": "List"}]                                                                                                                                                                                  6
# [{"target": "Age", "segment": "65"}, {"target": "MaxAge", "segment": "65"}, {"target": "MinAge", "segment": "65"}, {"target": "Region", "segment": "Missouri"}, {"target": "List"}]                                                                                                                                                     6
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Barack Obama"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                                                   6
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Missouri"}, {"target": "Segment", "segment": "US politics (liberal)"}]                                                                                                                                           5
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "St. Louis"}, {"target": "Website", "segment": "people who have visited their website or used one of their apps"}]                                                      5
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "Raytown"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}]                                                                       5
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Ethics"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}]                                                                                                              4
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "History"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                                                        4
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "University City"}]                                                                                                                                                     4
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Maryland Heights"}, {"target": "State", "segment": "Missouri"}]                                                                                                                                                    3
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Bernie Sanders"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "St. Louis"}]                                                                                                      3
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Bernie Sanders"}, {"target": "City", "segment": "Columbia"}, {"target": "State", "segment": "Missouri"}]                                                                                                       3
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "St. Louis"}, {"target": "Like"}]                                                                                                                                       3
# [{"target": "List"}, {"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                                                                                  3
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "AFL–CIO"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}]                                                                                                             3
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Cottleville"}, {"target": "State", "segment": "Missouri"}, {"target": "List"}]                                                                                                                                     3
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Community issues"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "St. Louis"}]                                                                                                    3
#                                                                                                                                                                                                                                                                                                                                        ..
# [{"target": "Age", "segment": "65"}, {"target": "MaxAge", "segment": "65"}, {"target": "MinAge", "segment": "65"}, {"target": "Region", "segment": "Maryland"}, {"target": "Interest", "segment": "Medicare (United States)"}, {"target": "Region", "segment": "Missouri"}, {"target": "Region", "segment": "Ohio"}]                    1
# [{"target": "Age", "segment": "65"}, {"target": "MaxAge", "segment": "65"}, {"target": "MinAge", "segment": "65"}, {"target": "Interest", "segment": "Medicare Advantage"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Alternative medicine"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}]                                                                                                1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Region", "segment": "Missouri"}, {"target": "Interest", "segment": "U.S. Senator Bernie Sanders"}]                                                                                                                                    1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Bridgeton"}, {"target": "State", "segment": "Missouri"}, {"target": "List"}]                                                                                                                                       1
# [{"target": "Age", "segment": "30 and older"}, {"target": "MinAge", "segment": "30"}, {"target": "City", "segment": "Cottleville"}, {"target": "Interest", "segment": "MSNBC"}, {"target": "State", "segment": "Missouri"}]                                                                                                             1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "Overland"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}]                          1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "St. Louis"}, {"target": "State", "segment": "Missouri"}]                                                                                                                                                           1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "Interest", "segment": "Public broadcasting"}, {"target": "City", "segment": "Raytown"}]                                                                                                   1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Barack Obama"}, {"target": "Interest", "segment": "CNN"}, {"target": "City", "segment": "Cottleville"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}]                1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Activism"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "St. Louis"}]                                                                                                            1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "Interest", "segment": "Politics and social issues"}, {"target": "City", "segment": "St. Louis"}]                                                                                          1
# [{"target": "Interest", "segment": "Anti-discrimination"}, {"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "St. Louis"}, {"target": "State", "segment": "Missouri"}]                                                                                                 1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "Overland"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}]                                                                      1
# [{"target": "Age", "segment": "25 and older"}, {"target": "MinAge", "segment": "25"}, {"target": "Interest", "segment": "Civil and political rights"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                                     1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "Raytown"}]                                                                                                                                                             1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Complex (magazine)"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "St. Louis"}]                                                                                                  1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Maryland Heights"}, {"target": "State", "segment": "Missouri"}, {"target": "List"}]                                                                                                                                1
# [{"target": "Age", "segment": "25 and older"}, {"target": "MinAge", "segment": "25"}, {"target": "City", "segment": "Kirksville"}, {"target": "State", "segment": "Missouri"}]                                                                                                                                                          1
# [{"target": "Interest", "segment": "CNN"}, {"target": "Age", "segment": "30 and older"}, {"target": "MinAge", "segment": "30"}, {"target": "City", "segment": "Cottleville"}, {"target": "State", "segment": "Missouri"}]                                                                                                               1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Segment", "segment": "<b>Light TV Viewers</b>."}, {"target": "Region", "segment": "Missouri"}]                                                                                                                                        1
# [{"target": "Age", "segment": "35 and older"}, {"target": "MinAge", "segment": "35"}, {"target": "City", "segment": "Cottleville"}, {"target": "State", "segment": "Missouri"}]                                                                                                                                                         1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "City", "segment": "Bellefontaine Neighbors"}, {"target": "State", "segment": "Missouri"}, {"target": "City", "segment": "University City"}, {"target": "Retargeting", "segment": "people who may be similar to their customers"}]     1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Barack Obama"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}]                                                                                                        1
# [{"target": "Age", "segment": "30 and older"}, {"target": "MinAge", "segment": "30"}, {"target": "City", "segment": "Maryland Heights"}, {"target": "State", "segment": "Missouri"}, {"target": "Segment", "segment": "US politics (liberal)"}]                                                                                         1
# [{"target": "Age", "segment": "21 and older"}, {"target": "MinAge", "segment": "21"}, {"target": "State", "segment": "Missouri"}, {"target": "Interest", "segment": "Politics"}, {"target": "City", "segment": "St. Louis"}]                                                                                                            1
# [{"target": "Age", "segment": "20 and older"}, {"target": "MinAge", "segment": "20"}, {"target": "State", "segment": "Missouri"}, {"target": "Interest", "segment": "Politics and social issues"}, {"target": "City", "segment": "University City"}]                                                                                    1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Middle class"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                                                   1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "American Civil Liberties Union"}, {"target": "City", "segment": "Mehlville"}, {"target": "State", "segment": "Missouri"}]                                                                                      1
# [{"target": "Age", "segment": "18 and older"}, {"target": "MinAge", "segment": "18"}, {"target": "Interest", "segment": "Construction"}, {"target": "Region", "segment": "Missouri"}]                                                                                                                                                   1
# Name: targets, Length: 182, dtype: int64
